# %% [markdown]
# # **<p style="font-family:newtimeroman;font-size:200%;text-align:center;color:##576393;">Electric Vehicle Adoption Analysis | Delaware United State </p>**

# %% [markdown]
# ![](https://i.postimg.cc/VvtLhXnw/623c78b8169188b933826f7d-Blog-Article.png)

# %% [markdown]
# # <p style="font-family:georgia;font-size:150%;text-align:center;color:#690e11;"> Project Objective </p>
# ## - ***`Project:` Delaware Electric Vehicle charge point Analysis in the United State ***
# ### **** (Courtesy : I have taken dataset from ‘HASSAN’ and followed  his work)****
# #### **<h1 align="center"><span style="color:#690e11;"> About me</span>**
# ### ***👋 Hi ! My name is Subashri rajendran . I'm excited to be starting my journey in Data science with my very first project on Kaggle. As a beginner in this field , I'm passionate about exploring different datasets,learning new techniques, and sharing my insights with the community.I have always been curious about how data can be transformed into meanigful stories. I'm particulary interest in gaining hands on experience in data analysis , visualization ,statistics and Machine Learning ***
#
# #### **<h1 align="center"><span style="color:#690e11;">Passion & Goals</span>**
# ### ***💡 I am passionate about diving into the world of data science using data to uncover meaningful insight. I believe every dataset has the story to tell, and I'm excited to explore those stories through my projects **
# ### ***🎯 My goal is to build strong foundation in Data analysis,statistics, Data visualization and Machine Learning Algorithms.By working on real-world datasets, I aim to enhance my proble-solving skills and gradully move towardsmore advanced topic like predictive modeling and anlyasis.  ***
#
# #### **<h1 align="center"><span style="color:#690e11;"> About Project </span>**
# ### ***🤝To analyze the locations, costs, and rebates of electric vehicle (EV) charging stations in Delaware to understand where they are installed, how much they cost, and how rebates are being used. The goal is to identify patterns and provide suggestions for better placement and funding of future charging stations ***
#
# #### **<h1 align="center"><span style="color:#690e11;">Contact Info</span>**
# ### ***Click on the link below to contact with me:***
#
# - ***Email:*** subashri2009@gmail.com
# - [LinkedIn](https://www.linkedin.com/in/subashri-rajendran-10406523/)
# - [Github](https://github.com/SubashriR-DS/SubashriR-DS)

# %% [markdown]
# <a id="title"></a>
# <h1 style='font-family: georgia; background-color:coral; font-size:350%; color:black; border-radius: 20px 50px;
#            text-align: center; border-bottom: 2px solid #E8BA91;
#            padding-left: 20px; padding-right: 20px; padding-bottom: 10px; padding-top: 10px;
#            '>Electric vehicle adoption Analysis </h1>
#
# <p style="font-size: 20px; font-family:georgia; text-align: justify;
#           padding-left: 20px; padding-right: 20px; padding-bottom: 10px; padding-top: 10px;">
#    <br>
#     <b><u>About the dataset</u></b> 💡<br>
#      This <a href="https://www.kaggle.com/datasets/msjahid/delaware-electric-vehicle-charging-station-rebate">Dataset</a> The Electric Vehicle Charging Stations in Delaware dataset provides detailed information about the existing EV charging infrastructure in the state of Delaware, USA. The dataset is designed to help analyze the availability and distribution of charging stations and the impact of state-provided rebates on their deployment. It offers insights into how charging stations are spread across various cities and counties, as well as the cost and financial incentives associated with these stations.
# </p>
# <center>
# <table style="
#   padding: 10px;
#   border-radius: 2px;
#   border: 4px solid gray;
#   font-family: georgia;
#   font-size: 16px;
#   width: 100%";
# >
#   <tr>
#     <th>Feature</th>
#     <th>Description</th>
#   </tr>
#   <tr>
#     <td>Award Number</td>
#     <td>Unique identifier for each rebate award</td>
#   </tr>
#   <tr>
#     <td>Month</td>
#     <td>Month when the rebate was awarded</td>
#   </tr>
#   <tr>
#     <td>Year</td>
#     <td>Year when the rebate was awarded</td>
#   </tr>
#   <tr>
#     <td>City</td>
#     <td> City where the charging station is located</td>
#   </tr>
#   <tr>
#     <td>Zip</td>
#     <td>ZIP code of the location of the charging station</td>
#   </tr>
#   <tr>
#     <td>Charging Station Brand</td>
#     <td>Brand or manufacturer of the charging station</td>
#   </tr>
#   <tr>
#     <td>County</td>
#     <td>County where the charging station is located</td>
#   </tr>
#   <tr>
#     <td>Cost of charging Station</td>
#     <td>Cost of the charging station</td>
#   </tr>
#   <tr>
#     <td>Rebate Amount</td>
#     <td>Amount of rebate awarded for the charging station</td>
#   </tr>
# </table>
# </center>

# %% [markdown]
# <left>
# <ul id="table_of_contents" style="background-color:black; font-size:120%; color:white; font-family:georgia;
#     padding: 10px; border-radius: 2px;border: 4px solid gray;"><h3><u>
#     Table of contents</u></h3>
#     <li> <a href="#step1" style="color:white;">Library & Configurations</a></li>
#     <li> <a href="#step2" style="color:white;">Load Dataset</a></li>
#     <li> <a href="#step3" style="color:white;">Columns formating</a></li>
#     <li> <a href="#step4" style="color:white;">Attribute Overview</a></li>
#     <li> <a href="#step5" style="color:white;">Missing Value Handling</a></li>
#     <li> <a href="#step6" style="color:white;">Duplicate Value Manage</a></li>
#     <li> <a href="#step7" style="color:white;">Statistical Data Summary</a></li>
#     <li> <a href="#step8" style="color:white;">Feature engineering</a></li>
#     <li> <a href="#step9" style="color:white;">Exploratory Data Analysis</a></li>
# </ul>
#
# <p style='font-family:georgia; font-size: 16px; background-color: "#202124"; padding:5px; color:white;'><i>Note: You can click icons at the right of titles to <b>Return</b> to the table of contents.</i></p>

# %% [markdown]
# The Electric Vehicle Charging Stations in Delaware dataset provides detailed information about the existing EV charging infrastructure in the state of Delaware, USA. The dataset is designed to help analyze the availability and distribution of charging stations and the impact of state-provided rebates on their deployment. It offers insights into how charging stations are spread across various cities and counties, as well as the cost and financial incentives associated with these stations.

# %% [markdown]
# # <a id='step1'></a>
# # <div style="background-color:coral;color:black;background-size: cover;font-family:georgia;font-size:175%;text-align:center;border-radius:20px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 1 | <b></span><span style="color:#f2f2f2"><b>Library & Configurations</b></span></div>

# %%
# Magic command
#%%time    

# Importing Libraries
from gc import collect;  # garbage collection to free up memory
from warnings import filterwarnings;
filterwarnings('ignore'); 

#Importing Common Libraries
import re  # regular expressions
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import numpy as np  # linear algebra

#Visualization Libraries
import matplotlib.pyplot as plt  # data visualization
import seaborn as sns  # statistical data visualization

#plot style
plt.style.use("fivethirtyeight")

#Importing Date and Time Functions
from datetime import datetime  # Importing the datetime class from the datetime module

#Utility Libraries
from itertools import cycle, combinations  # generating combinations & cycle

#Formatting Tables with tabulate
from tabulate import tabulate  # Importing tabulate library for formatting tables

#Working with String Buffers
from io import StringIO

#Importing Statistical Functions
from scipy import stats  # statistical functions

#Displaying and Clearing Output in IPython
from IPython.display import display, HTML, display_html, clear_output  # displaying HTML content

#Clearing Output and Calling Garbage Collection
clear_output();          # clr prev output
print();                 # adding space b/w output
collect();               # manage memory usage for longrunning notebook   when use large datasets

# %%
import time

print("Start of the program...")
time.sleep(2)  # Program pauses for 2 seconds
print("This message appears after a 2-second delay.")
# Out:
# Start of the program...
# This message appears after a 2-second delay.

# %%
class color:
    GRAY = '\033[90m'
    LIGHT_BLUE = '\033[94m'
    BLUE = '\033[94m'
    CYAN = '\033[96m'
    BOLD = '\033[1m'
    RED = '\033[91m'
    END = '\033[0m'
    UNDERLINE = '\033[4m'
    GREEN = '\033[92m'
    YELLOW = '\033[93m'
    MAGENTA = '\033[95m'
    WHITE = '\033[97m'
    BLACK = '\033[30m'
    LIGHT_RED = '\033[91m'
    LIGHT_GREEN = '\033[92m'
    LIGHT_YELLOW = '\033[93m'
    LIGHT_BLUE = '\033[94m'
    LIGHT_MAGENTA = '\033[95m'
    LIGHT_CYAN = '\033[96m'
    LIGHT_WHITE = '\033[97m'
    RESET = '\033[0m'

# Define global styling properties
global_style = {
    "background-color": "#ff4d4d",
    "color": "#e6e6ff",
    "border": "1.5px solid black",
    "font-weight": "bold"
}

# %%
# Set the plot style to 'fivethirtyeight'
plt.style.use("fivethirtyeight")
sns.set(rc={"figure.figsize":(10, 10)})
print(f"{color.GREEN}Succesfully Configured libraries!{color.END}")
# Out:
# Succesfully Configured libraries!

# %% [markdown]
# # <a id='step2'></a>
# # <div style="background-color:coral;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 2 | <b></span><span style="color:#f2f2f2"><b>Load Dataset</b></span></div>

# %%
# %%time

# Error Handling When Loading Dataset with Pandas read_csv

try:
    # Attempt to read the dataset
    df = pd.read_csv('delaware_ev_charging_rebates.csv')
    print(f"{color.GREEN}Dataset loaded successfully.{color.END}")
    
except FileNotFoundError:
    # Handle FileNotFoundError if the file does not exist
    print(f"{color.RED}Error: File not found. Please check the file path.{color.END}")

except Exception as e:
    # Handle other exceptions
    print(f"{color.RED}An error occurred while loading the dataset: {e}{color.END}")

print(color.BLUE)
collect();
# Out:
# Dataset loaded successfully.
#
# CPU times: total: 62.5 ms
# Wall time: 123 ms

# %% [markdown]
# # <a id='step3'></a>
# # <div style="background-color:coral;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 3 | <b></span><span style="color:#f2f2f2"><b>Columns formating</b></span></div>

# %%
# Nested Function for column name statndarize,replace all non-alpha numberic charecter to' _'

def format_column_name(df):
    # Define a function to format a single column name
    def format_single_column_name(column_name):
        # Replace non-alphanumeric characters with underscores
        column_name = re.sub(r'\W+', '_', column_name)
        # Convert to lowercase
        column_name = column_name.lower()
        # Remove leading or trailing underscores
        column_name = column_name.strip('_')
        return column_name  # Return the modified column name
    
    # Apply format_single_column_name function to each column name
    mapped_names = [format_single_column_name(col) for col in df.columns]
    
    # Create a dictionary mapping original column names to modified column names
    column_mapping = dict(zip(df.columns, mapped_names))
    
    # Rename columns using the mapping
    df = df.rename(columns=column_mapping)
    
    return df

# %%
previous_name = df.copy()

# Apply the function to clean column names
df = format_column_name(df)

# Rename columns to lowercase and replace spaces with underscores
renamed_columns = pd.DataFrame({
    'Previous Name': [color.RED + col + color.RESET for col in previous_name.columns],
    'New Name': [color.GREEN + col + color.RESET for col in df.columns]
})

# Pretty print using tabulate for better formatting
print(tabulate(renamed_columns, headers='keys', tablefmt='grid'))

# Apply the function to clean column names
df = format_column_name(df)
# Out:
# +----+--------------------------+--------------------------+
# |    | Previous Name            | New Name                 |
# +====+==========================+==========================+
# |  0 | Award Number             | award_number             |
# +----+--------------------------+--------------------------+
# |  1 | Month                    | month                    |
# +----+--------------------------+--------------------------+
# |  2 | Year                     | year                     |
# +----+--------------------------+--------------------------+
# |  3 | City                     | city                     |
# +----+--------------------------+--------------------------+
# |  4 | Zip                      | zip                      |
# +----+--------------------------+--------------------------+
# |  5 | Charging Station Brand   | charging_station_brand   |
# +----+--------------------------+--------------------------+
# ...

# %% [markdown]
# # <a id='step4'></a>
# # <div style="background-color:coral;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 4 | <b></span><span style="color:#f2f2f2"><b>Attribute Overview</b></span></div>>

# %%
def display_dataframe_with_custom_header(df, show_head=False):
    # Define global styling properties
    global_style = {
        "background-color": "#2e3440",
        "color": "#FFFF00",
        "border": "1.5px solid black",
        "font-weight": "bold",
        "font-family": "'Courier New', Courier, monospace"  # Use monospace font for table view
    }

    # Add custom text at the top with "Poetsen One" font and wave effect
    header_text = """
    <h2 style='color: #FF5733; font-weight: bold; font-family: "Poetsen One", sans-serif;
                animation: wave 1.5s infinite;'>
        D<span style="color: #FFFF00;">A</span>T<span style="color: #FFFF00;">A</span>FRAME 
        {frame_type} 
    </h2><br>

    <style>
    @keyframes wave {{
        0% {{ transform: rotate(-2deg); }}
        50% {{ transform: rotate(2deg); }}
        100% {{ transform: rotate(-2deg); }}
    }}
    </style>
    """

    if show_head:
        frame_type = "HEAD"  # Change frame type to "HEAD" for head display
    else:
        frame_type = "INFORMATION"  # Default to "INFORMATION" for info display

    header_text = header_text.format(frame_type=frame_type)  # Format the header text

    if show_head:
        # Get the head of the DataFrame
        df_to_display = df.head()

        # Convert head DataFrame to HTML table
        df_html = df_to_display.to_html(index=False, classes='styled-table', header=True)

        # Apply styling to the table
        styled_df = f'''
        <style>
        .styled-table {{
            border-collapse: collapse;
            margin: 25px 0;
            font-size: 0.9em;
            font-family: sans-serif;
            min-width: 400px;
            box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
        }}
        .styled-table thead th {{
            padding-top: 12px;
            padding-bottom: 12px;
            text-align: left;
            background-color: #90EE90;
            color: ##81a1c1;
            border: 1px solid #ddd;
            font-weight: bold;
        }}
        .styled-table tbody td {{
            padding: 12px 15px;
            border: 1px solid #ddd;
        }}

        .wave-animation {{
            animation: wave 1.5s infinite;
        }}
        </style>
        {header_text}
        {df_html}
        '''
    else:
        # Redirect printed output to a string
        info_output = StringIO()
        with pd.option_context('display.max_info_rows', 1000, 'display.max_info_columns', 1000):
            df.info(buf=info_output)

        # Get the printed info as a string
        info_string = info_output.getvalue()

        # Apply styling to the string
        styled_df = f'''
        {header_text}
        <pre style="{";".join([f"{key}: {value}" for key, value in global_style.items()])};">
        {info_string}
        </pre>
        '''

    # Google Fonts link
    google_fonts_link = "<link href='https://fonts.googleapis.com/css2?family=Poetsen+One&display=swap' rel='stylesheet'>"

    # HTML content including Google Fonts link and styled DataFrame
    html_content = f'''
    <!DOCTYPE html>
    <html>
    <head>
        <meta charset="UTF-8">
        <meta name="viewport" content="width=device-width, initial-scale=1.0">
        <title>Dataframe Information</title>
        {google_fonts_link}
    </head>
    <body>
        {styled_df}
    </body>
    </html>
    '''

    # Display HTML content
    display(HTML(html_content))

# %%
display_dataframe_with_custom_header(df)
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#         <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <title>Dataframe Information</title>
#         <link href='https://fonts.googleapis.com/css2?family=Poetsen+One&display=swap' rel='stylesheet'>
#     </head>
#     <body>
#
#
#     <h2 style='color: #FF5733; font-weight: bold; font-family: "Poetsen One", sans-serif;
#                 animation: wave 1.5s infinite;'>
#         D<span style="color: #FFFF00;">A</span>T<span style="color: #FFFF00;">A</span>FRAME
#         INFORMATION
#     </h2><br>
#
#     <style>
#     @keyframes wave {
#         0% { transform: rotate(-2deg); }
#         50% { transform: rotate(2deg); }
#         100% { transform: rotate(-2deg); }
#     }
#     </style>
#
#         <pre style="background-color: #2e3440;color: #FFFF00;border: 1.5px solid black;font-weight: bold;font-family: 'Courier New', Courier, monospace;">
# ...

# %%
display_dataframe_with_custom_header(df, show_head=True)
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#         <meta charset="UTF-8">
#         <meta name="viewport" content="width=device-width, initial-scale=1.0">
#         <title>Dataframe Information</title>
#         <link href='https://fonts.googleapis.com/css2?family=Poetsen+One&display=swap' rel='stylesheet'>
#     </head>
#     <body>
#
#         <style>
#         .styled-table {
#             border-collapse: collapse;
#             margin: 25px 0;
#             font-size: 0.9em;
#             font-family: sans-serif;
#             min-width: 400px;
#             box-shadow: 0 0 20px rgba(0, 0, 0, 0.15);
#         }
#         .styled-table thead th {
#             padding-top: 12px;
#             padding-bottom: 12px;
#             text-align: left;
#             background-color: #90EE90;
#             color: ##81a1c1;
#             border: 1px solid #ddd;
#             font-weight: bold;
#         }
#         .styled-table tbody td {
#             padding: 12px 15px;
# ...

# %% [markdown]
# # <a id='step5'></a>
# # <div style="background-color:coral;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 5 | <b></span><span style="color:#f2f2f2"><b>Missing Value Handling</b></span></div>

# %%
def plot_missing_values_heatmap(df):
    # Calculate the sum of missing values excluding the first column
    missing_values_sum = df.isna().iloc[:, 1:].sum()

    # Create a heatmap plot
    plt.figure(figsize=(22, 4), facecolor='silver')
    ax = sns.heatmap(missing_values_sum.to_frame(name='').T.rename(columns=lambda x: x.replace('_', ' ').title()), 
                     cmap=sns.dark_palette("gray", as_cmap=True), annot=True, fmt='0.0f',
                     annot_kws={"fontsize":30, "fontweight": "bold"},  # Adjust font size and weight for annotations
                     linecolor='silver', linewidth=1)

    # Set title and adjust fontsize
    plt.title('Count of Missing Values', fontsize=18, fontweight='bold')

    # Rotate the x-axis labels
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right', fontsize=15, fontweight='bold')

    # Adjust font size and weight of y-axis labels
    ax.set_yticklabels(ax.get_yticklabels(), fontsize=15, fontweight='bold')

    # Show the plot
    plt.show()

# %%
# Call the function to plot the heatmap
plot_missing_values_heatmap(df)

# %% [markdown]
# # <a id='step6'></a>
# # <div style="background-color:coral;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 6 | <b></span><span style="color:#f2f2f2"><b>Duplicate Value Manage</b></span></div>

# %%
def apply_duplicated_styling(df):
    
    # Define a function to apply font size and color to values
    def apply_style(value):
        if value:
            return 'font-size: 20px; color: red'
        else:
            return 'font-size: 20px; color: green'

    # Define a function to apply font size to column names
    def apply_column_name_style(value):
        return 'font-size: 20px'

    # Transpose the DataFrame and check for duplicated values along the rows
    column_duplicates = df.T.duplicated()

    # Apply styling to the DataFrame containing duplicated values
    styled_column_duplicates = column_duplicates.to_frame().style.applymap(apply_style).background_gradient(axis=0)

    # Apply styling to the column names
    styled_column_duplicates.set_table_styles([{'selector': 'th', 'props': [('font-size', '20px')]}])

    return styled_column_duplicates

# %%
# Drop the first column from df
df_without_first_column = df.drop(df.columns[0], axis=1)
df_without_first_column
# Out:
#      month  year        city    zip charging_station_brand      county  \
# 0        6  2018   Hockessin  19707                  Tesla  New Castle
# 1        6  2018  Wilmington  19802          AeroVironment  New Castle
# 2        6  2018  Middletown  19709            ChargePoint  New Castle
# 3        6  2018        Bear  19701                  Tesla  New Castle
# 4        6  2018        Bear  19701          Clipper Creek  New Castle
# ..     ...   ...         ...    ...                    ...         ...
# 712     11  2022     Seaford  19973               Juicebox  New Castle
# 713     11  2022      Elkton  19711               Juicebox  New Castle
# 714      2  2023  Wilmington  19801          JuicePedastal  New Castle
# 715      2  2023       Lewes  19971            SemaConnect      Sussex
# 716      2  2023        Bear  19701          JuicePedastal  New Castle
#
#      cost_of_charging_station  rebate_amount
# 0                       500.0          250.0
# ...

# %%
# checks for duplicates among the columns of the DataFrame.
styled_df = apply_duplicated_styling(df_without_first_column)
styled_df
# Out:
# <style type="text/css">
# #T_fcfe8 th {
#   font-size: 20px;
# }
# #T_fcfe8_row0_col0, #T_fcfe8_row1_col0, #T_fcfe8_row2_col0, #T_fcfe8_row3_col0, #T_fcfe8_row4_col0, #T_fcfe8_row5_col0, #T_fcfe8_row6_col0, #T_fcfe8_row7_col0 {
#   font-size: 20px;
#   color: green;
# }
# </style>
# <table id="T_fcfe8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fcfe8_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fcfe8_level0_row0" class="row_heading level0 row0" >month</th>
#       <td id="T_fcfe8_row0_col0" class="data row0 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fcfe8_level0_row1" class="row_heading level0 row1" >year</th>
#       <td id="T_fcfe8_row1_col0" class="data row1 col0" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fcfe8_level0_row2" class="row_heading level0 row2" >city</th>
#       <td id="T_fcfe8_row2_col0" class="data row2 col0" >False</td>
# ...

# %% [markdown]
# # <a id='step7'></a>
# # <div style="background-color:coral;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 7 | <b></span><span style="color:#f2f2f2"><b>Statistical Data Summary</b></span></div>

# %%
def calculate_statistics(df, opacity=0.5, font_size='17px'):
    # Filter numeric columns
    numeric_df = df.select_dtypes(include=['number'])
    
    stat = pd.DataFrame()  # Initialize an empty dataframe

    # Measure of central tendency
    stat['Mean'] = numeric_df.mean()  # for mean of all columns
    stat['Median'] = numeric_df.median()  # for median of all columns
    stat['Mode'] = numeric_df.mode().iloc[0]  # for mode of all columns

    # Measure of dispersion
    stat['Range'] = (numeric_df.max() - numeric_df.min())
    stat['Stdev'] = numeric_df.std()
    stat['Variance'] = numeric_df.var()

    # Interquartile range
    stat['IQR'] = [stats.iqr(numeric_df[i]) for i in numeric_df.columns]

    # Quantiles
    stat['25%'] = numeric_df.quantile(q=0.25, axis=0)
    stat['50%'] = numeric_df.quantile(q=0.50, axis=0)
    stat['75%'] = numeric_df.quantile(q=0.75, axis=0)

    # Minimum and maximum
    stat['Min'] = numeric_df.min()
    stat['Max'] = numeric_df.max()

    # Skewness and Kurtosis
    stat['Skewness'] = numeric_df.skew()
    stat['Kurtosis'] = numeric_df.kurt()

    # Transpose the DataFrame
    stat = stat.T

    # Apply the float format
    stat = stat.applymap('{:,.2f}'.format)

    # Apply the background color with transparency
    styled_df = stat.style.apply(lambda x: [f'background: rgba(173, 216, 230, {opacity})' for val in x], axis=1)
    
    # Apply font size
    styled_df = styled_df.set_properties(**{'font-size': font_size})
    
    return styled_df

# %%
# Assuming you have a DataFrame called 'df' and want to set transparency to 0.5
stats_df = calculate_statistics(df, opacity=0.4, font_size='19px')
stats_df
# Out:
# <style type="text/css">
# ...

# %%
def variable_summary(df, opacity=0.5, font_size='20px'):
    # Initialize an empty list to store individual summaries
    summaries = []

    # Iterate through each column in the DataFrame
    for col in df.columns:
        dtype = df[col].dtype  # Data type of the column
        count = df[col].count()  # Count of non-null values
        unique = df[col].nunique()  # Number of unique values
        missing = df[col].isna().sum()  # Number of missing values

        # Append the summary information to the list
        summaries.append([col, dtype, count, unique, missing])

    # Create a DataFrame from the list of summaries
    summary_df = pd.DataFrame(summaries, columns=['Variable', 'Dtype', 'Count', 'Unique', 'Missing'])

    # Apply background color with opacity
    styled_summary_df = summary_df.style.apply(lambda x: [f'background: rgba(42, 46, 120, {opacity})' for val in x], axis=1)

    # Apply font size to the entire DataFrame
    styled_summary_df.set_table_styles([{'selector': '', 'props': [('font-size', font_size)]}])

    return styled_summary_df

# %%
# DataFrame called 'df'
summary_df = variable_summary(df_without_first_column)
summary_df
# Out:
# <style type="text/css">
# #T_3abb7  {
#   font-size: 20px;
# }
# #T_3abb7_row0_col0, #T_3abb7_row0_col1, #T_3abb7_row0_col2, #T_3abb7_row0_col3, #T_3abb7_row0_col4, #T_3abb7_row1_col0, #T_3abb7_row1_col1, #T_3abb7_row1_col2, #T_3abb7_row1_col3, #T_3abb7_row1_col4, #T_3abb7_row2_col0, #T_3abb7_row2_col1, #T_3abb7_row2_col2, #T_3abb7_row2_col3, #T_3abb7_row2_col4, #T_3abb7_row3_col0, #T_3abb7_row3_col1, #T_3abb7_row3_col2, #T_3abb7_row3_col3, #T_3abb7_row3_col4, #T_3abb7_row4_col0, #T_3abb7_row4_col1, #T_3abb7_row4_col2, #T_3abb7_row4_col3, #T_3abb7_row4_col4, #T_3abb7_row5_col0, #T_3abb7_row5_col1, #T_3abb7_row5_col2, #T_3abb7_row5_col3, #T_3abb7_row5_col4, #T_3abb7_row6_col0, #T_3abb7_row6_col1, #T_3abb7_row6_col2, #T_3abb7_row6_col3, #T_3abb7_row6_col4, #T_3abb7_row7_col0, #T_3abb7_row7_col1, #T_3abb7_row7_col2, #T_3abb7_row7_col3, #T_3abb7_row7_col4 {
#   background: rgba(42, 46, 120, 0.5);
# }
# </style>
# <table id="T_3abb7">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# # <a id='step8'></a>
# # <div style="background-color:coral ;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 8 | <b></span><span style="color:#f2f2f2"><b>Feature engineering</b></span></div>

# %%
def map_to_season(month):
    # Map months to seasons
    if month in [3, 4, 5]:
        return "Spring"
    elif month in [6, 7, 8]:
        return "Summer"
    elif month in [9, 10, 11]:
        return "Autumn"
    else:
        return "Winter"
    
df['season'] = df['month'].apply(map_to_season)
df
# Out:
#     award_number  month  year        city    zip charging_station_brand  \
# 0     RCS0618102      6  2018   Hockessin  19707                  Tesla
# 1     RCS0618103      6  2018  Wilmington  19802          AeroVironment
# 2     RCS0618104      6  2018  Middletown  19709            ChargePoint
# 3     RCS0618105      6  2018        Bear  19701                  Tesla
# 4     RCS0618106      6  2018        Bear  19701          Clipper Creek
# ..           ...    ...   ...         ...    ...                    ...
# 712  MDCS1122058     11  2022     Seaford  19973               Juicebox
# 713  MDCS1122059     11  2022      Elkton  19711               Juicebox
# 714  MDCS0223061      2  2023  Wilmington  19801          JuicePedastal
# 715  MDCS0423063      2  2023       Lewes  19971            SemaConnect
# 716  MDCS0423064      2  2023        Bear  19701          JuicePedastal
#
#          county  cost_of_charging_station  rebate_amount  season
# ...

# %% [markdown]
# # <a id='step9'></a>
# # <div style="background-color:coral;background-size: cover;font-family:tahoma;font-size:175%;text-align:center;border-radius:25px 50px; padding:10px; border:solid 2px #09375b"><span style="color:gold"><b>Step 9 | <b></span><span style="color:#f2f2f2"><b>Exploratory Data Analysis</b></span></div>

# %%
class Plotter:
    @staticmethod
    def format_func(value, tick_number):
        if int(value) == value:  # Check if the value is an integer
            return f'{int(value)}'
        else:
            return f'{round(value, 2)}'

    @staticmethod
    def plot_kde_histogram(df, columns, columns_per_row=3):
        
        # Set the seaborn style to remove white grid lines
        sns.set_style("dark")
    
        # Choose a color palette with enough colors for all the columns
        palette = sns.color_palette("dark", len(columns))

        # Calculate the number of rows required based on the number of columns and columns per row
        num_cols = len(columns)
        num_rows = (num_cols - 1) // columns_per_row + 1

        # Create figure and axes
        fig, axs = plt.subplots(num_rows, columns_per_row, figsize=(14, 4.5 * num_rows), facecolor='silver')

        # Flatten axes for easier iteration
        axs = axs.flatten()

        # Set subplot background color
        subplot_color = 'silver'

        # Loop through each numeric column in the dataset
        for i, col in enumerate(columns):
            if i < num_cols:  # Ensure not to exceed the number of columns
                row_index = i // columns_per_row  # Calculate the row index
                col_index = i % columns_per_row   # Calculate the column index

                sns.kdeplot(data=df[col], color=palette[i], fill=True, ax=axs[i])
                axs[i].set(facecolor=subplot_color, ylabel='', xlabel='')  # Set subplot background color

                # Set plot title
                title = col.replace('_', ' ').title()  # Convert column name to title format
                axs[i].set_title(f'KDE - {title}', color=palette[i], fontname='Serif', fontsize=14)

                # Rotate x-axis labels to 90 degrees for better readability
                axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=0)
                skewness = df[col].skew()
                axs[i].legend(["Skewness: %.2f" % skewness], facecolor='gray')

                # Set custom formatter for x-axis ticks to display integers or floating point numbers
                # axs[i].xaxis.set_major_formatter(FuncFormatter(Plotter.format_func)) 
                # axs[i].yaxis.set_major_formatter(FuncFormatter(Plotter.format_func)) 

        # Hide empty axes if there are fewer columns than the allocated number of subplots
        for j in range(num_cols, num_rows * columns_per_row):
            fig.delaxes(axs[j])

        # Adjust layout
        plt.tight_layout()

        # Show plot
        plt.show()

    @staticmethod
    def plot_hist_histogram(df, columns, columns_per_row=3):
        
        # Set the seaborn style to remove white grid lines
        sns.set_style("dark")
        
        # Choose a color palette with enough colors for all the columns
        palette = sns.color_palette("dark", len(columns))

        # Calculate the number of rows required based on the number of columns and columns per row
        num_cols = len(columns)
        num_rows = (num_cols - 1) // columns_per_row + 1

        # Calculate the actual number of subplots needed based on the number of columns
        num_plots = min(num_cols, columns_per_row * num_rows)

        # Create figure and axes
        fig, axs = plt.subplots(num_rows, columns_per_row, figsize=(14, 4.5 * num_rows), facecolor='silver')

        # Flatten axes for easier iteration
        axs = axs.flatten()

        # Set subplot background color
        subplot_color = 'silver'

        # Loop through each numeric column in the dataset
        for i, col in enumerate(columns):
            if i < num_plots:  # Ensure not to exceed the number of subplots needed
                row_index = i // columns_per_row  # Calculate the row index
                col_index = i % columns_per_row   # Calculate the column index

                sns.histplot(data=df, x=col, color=palette[i], kde=True, bins=round(np.sqrt(len(df))), ax=axs[i])
                axs[i].set(facecolor=subplot_color, ylabel='', xlabel='')  # Set subplot background color

                # Set plot title
                title = col.replace('_', ' ').title()  # Convert column name to title format
                axs[i].set_title(title, color=palette[i], fontname='Serif', fontsize=14)

                # Rotate x-axis labels to 45 degrees
                axs[i].set_xticklabels(axs[i].get_xticklabels(), rotation=0)
                skewness = df[col].skew()
                axs[i].legend(["Skewness: %.2f" % skewness], facecolor='gray')


        # Hide empty axes if there are fewer columns than the allocated number of subplots
        for j in range(num_plots, num_rows * columns_per_row):
            fig.delaxes(axs[j])

        # Adjust layout
        plt.tight_layout()

        # Show plot
        plt.show()

# %%
columns = ['cost_of_charging_station','rebate_amount']
Plotter.plot_hist_histogram(df, columns, columns_per_row=2)

# %%
Plotter.plot_kde_histogram(df, columns, columns_per_row=2)

# %%
def plot_scatter_by_category(df, x_column, y_column, category_columns, title):
    # Create a color palette for each unique category in all category columns
    num_categories = sum(df[column].nunique() for column in category_columns)
    category_palette = sns.color_palette("husl", num_categories)

    # Create figure and axes objects
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 8), sharex=True, sharey=True, facecolor='silver')

    # Scatter plot by category columns
    for i, column in enumerate(category_columns):
        categories = df[column].unique()
        for j, category in enumerate(categories):
            axes[i].scatter(df[x_column][df[column] == category], 
                            df[y_column][df[column] == category], 
                            label=f'{category}', 
                            color=category_palette[j])

        # Set labels and title for the subplot
        axes[i].set_xlabel(x_column.title())
        axes[i].set_ylabel(y_column.title())
        axes[i].set_title(title)
        # Show legend for the entire plot
        axes[i].legend(title=category_columns[i].title(), facecolor='gray')



    # Show plot
    plt.tight_layout()
    plt.show()

# %%
plot_scatter_by_category(df, 'year', 'cost_of_charging_station', ['county', 'season'], 'Charging Station Costs by County and Season')

# %%
def plot_brand_distribution(df, columns, subplot_color='silver', custom_palettes=None):
    default_palettes = ["Set1", "husl", "Paired", "Set2", "Set3", "coolwarm", "pastel", "colorblind"]
    
    if custom_palettes is None:
        custom_palettes = default_palettes
    elif not isinstance(custom_palettes, list):
        raise ValueError("custom_palettes must be a list of palette names")
    
    for column_name, palette_name in zip(columns, cycle(custom_palettes)):
        # Calculate the counts of each column
        column_counts = df[column_name].value_counts()

        # Get the custom color palette for the current column
        custom_palette = sns.color_palette(palette_name)

        # Plotting
        fig, axes = plt.subplots(1, 2, figsize=(14, 6), facecolor=subplot_color)

        # Countplot for the distribution of the column
        sns.countplot(data=df, x=column_name, ax=axes[0], palette=custom_palette)
        axes[0].set_xlabel(column_name.replace('_', ' ').title())
        axes[0].set_ylabel('Count')
        axes[0].set_facecolor(subplot_color)  # Set subplot background color

        # Pie chart for the distribution of the column
        axes[1].pie(column_counts.values, labels=column_counts.index, autopct='%1.2f%%', colors=custom_palette)
        axes[1].set_facecolor(subplot_color)  # Set subplot background color

        # Set titles for the column plots
        title_color = sns.color_palette("Set1")[0]
        axes[0].set_title(f'Distribution of {column_name.replace("_", " ").title()}', color=title_color)
        axes[1].set_title(f'Distribution of {column_name.replace("_", " ").title()}', color=title_color)

        # Set the super title color to the first color of the colorblind palette
        suptitle_color = sns.color_palette("colorblind")[0]

        plt.suptitle(f'Analysis of {column_name.replace("_", " ").title()} Distribution', fontsize=16, color=suptitle_color)

        # Adjust layout
        plt.tight_layout()

        # Show the plot
        plt.show()

# %%
plot_brand_distribution(df, columns=['county'])

# %%
def plot_category_count(df, column_name, title='', facecolor='silver', palette='dark'):
    # Calculate the count of each category
    category_counts = df[column_name].value_counts()

    # Get the index of categories sorted by count in ascending order
    sorted_categories = category_counts.index

    # Set the background color
    sns.set_style(rc={'axes.facecolor': facecolor})

    # Convert palette to a list if it's a string
    if isinstance(palette, str):
        palette = sns.color_palette(palette, len(sorted_categories))

    # Plotting
    plt.figure(figsize=(14, 6), facecolor=facecolor)
    ax = sns.countplot(data=df, x=column_name, order=sorted_categories, palette=palette)

    # Set the column name labels' color based on the palette
    num_colors = len(palette)
    for i, label in enumerate(ax.get_xticklabels()):
        label.set_color(palette[i % num_colors])

    plt.xlabel(column_name.replace('_', ' ').title())
    plt.xticks(rotation=90)
    plt.title(title, pad=20, fontsize=18, color='#FF5733', fontname='Calibri', fontweight='bold')  # Set the title
    plt.show()

# %%
# Example usage:
title = 'City Charging Station Availability Overview'
plot_category_count(df, column_name='city', title=title)
# Example usage:
title = 'Charging Station Brand Distribution'
plot_category_count(df, column_name='charging_station_brand', title=title)

# %%
plt.figure(figsize=(10, 6), facecolor='silver')
sns.pointplot(x="month", y='cost_of_charging_station', data=df, color="darkblue")
plt.title('Monthly Charging Cost')
plt.xlabel('Month')
plt.ylabel('Count of Charging Cost')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
def plot_by_year(df, x='', y='', title=''):
    plt.figure(figsize=(20, 8), facecolor='silver')

    # Lineplot
    plt.subplot(3, 1, 1, facecolor='silver')
    sns.lineplot(data=df, x=x, y=y, color="green")
    plt.title(f'Lineplot of {title}', color='black')  # Title with variable title
    plt.xlabel(x.replace('_', ' ').title())
    plt.ylabel(y.replace('_', ' ').title())

    # Pointplot
    plt.subplot(3, 1, 2, facecolor='silver')
    sns.pointplot(data=df, x=x, y=y, color="orange")
    plt.title(f'Pointplot of {title}', color='black')  # Title with variable title
    plt.xlabel(x.replace('_', ' ').title())
    plt.ylabel(y.replace('_', ' ').title())

    # Barplot
    plt.subplot(3, 1, 3, facecolor='silver')
    sns.barplot(data=df, x=x, y=y, palette="viridis")
    plt.title(f'Barplot of {title}', color='black')  # Title with variable title
    plt.xlabel(x.replace('_', ' ').title())
    plt.ylabel(y.replace('_', ' ').title())

    plt.tight_layout()
    plt.show()

# %%
# Example usage
plot_by_year(df, x='year', y='cost_of_charging_station', title='Yearly Charging Cost')

# %%
def plot_by_unique(df, x='', y='', hue='', unique_columns='', title=''):
    for column_value in df[unique_columns].unique():
        plt.figure(figsize=(20, 6), facecolor='silver')
        
        # Plotting
        ax = sns.barplot(x=x, y=y, hue=hue, 
                         data=df[df[unique_columns] == column_value], ci=None, palette="Set1")

        plt.title(f'{title} by {hue} in {column_value} {unique_columns.title()}', color='black')  # Updated title
        plt.xlabel(x.replace('_', ' ').title())
        plt.ylabel(y.replace('_', ' ').title())

        plt.tight_layout()
        # Set legend facecolor to gray
        legend = ax.legend(facecolor='gray')
        plt.show()

# %%
# Example usage
plot_by_unique(df, x='year', y='cost_of_charging_station', hue='season', unique_columns='county', title='Charging Station Costs')

# %%
def plot_costs(df, x='', y='', hue='', title=''):
    plt.figure(figsize=(14, 8), facecolor='silver')
    ax = sns.barplot(x=x, data=df, palette="muted", y=y, hue=hue, ci=None)
    plt.title(f'{title} by Season and County')
    plt.xlabel(x.replace('_', ' ').title())
    plt.ylabel(y.replace('_', ' ').title())

    for p in ax.patches:
        ax.annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha='center', va='center', xytext=(0, 10), textcoords='offset points')

    plt.legend(title=hue.replace('_', ' ').title())
    # Set legend facecolor to gray
    legend = ax.legend(facecolor='gray')
    plt.show()

# %%
# Example usage
plot_costs(df, x = 'season', y='cost_of_charging_station', hue='county', title='Charging Station Costs')

# %%
# Example usage
plot_costs(df, x = 'season', y='rebate_amount', hue='county', title='Rebate Amount')

# %%
plt.figure(figsize=(10, 6), facecolor='silver')
sns.pointplot(x="month", y='rebate_amount', data=df, color="darkblue")
plt.title('Monthly Rebate Amount')
plt.xlabel('Month')
plt.ylabel('Count of Rebate Amount')
plt.show()

# %%
plot_by_year(df, x='year', y='rebate_amount', title='Yearly Rebate Amount')

# %%
# Example usage
plot_by_unique(df, x='year', y='rebate_amount', hue='season', unique_columns='county', title='Rebate Amount')
